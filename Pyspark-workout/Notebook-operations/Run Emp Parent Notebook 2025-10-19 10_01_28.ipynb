# %%
# Run the child notebook with parameters - Team
_count=dbutils.notebook.run("Emp Program child Notebook 2025-10-19 10_00_28",600,{"team" : "Finance"})

# %%
print(f"child nootbook count {_count}")
