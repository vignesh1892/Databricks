# %%
df= spark.read.format("csv").options(header=True).load("/Volumes/databricks_practice/inputdb/customerdata/customers.csv")
df.display()

# %%
outputfile="/Volumes/databricks_practice/outputdb/customerdata/customers.csv"
df.write.mode("append").options(header=True).csv(outputfile)
