# %%
# %sql
-- Create temp view using SQL query
CREATE OR REPLACE TEMP VIEW temp_view
USING CSV
OPTIONS (
  inferSchema "true",
  header "true",
  path "dbfs:/Volumes/spark_workouts/customerdb/customerfile/cusdata/"
);

SELECT * FROM temp_view;

# %%
# %sql
select * from _sqldf

# %%
spark.sql("""SELECT * FROM csv.`dbfs:/Volumes/spark_workouts/customerdb/customerfile/cusdata/` """).display();
