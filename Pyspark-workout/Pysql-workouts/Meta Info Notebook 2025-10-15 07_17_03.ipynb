# %%
spark.sql("show volumes in databricks_practice.inputdb").display()

# %%
spark.sql("show tables in databricks_practice.inputdb").display()

# %%
display(dbutils.fs.ls("/Volumes/databricks_practice/outputdb/customerdata"))
