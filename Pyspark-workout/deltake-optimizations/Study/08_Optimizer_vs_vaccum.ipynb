# %% [markdown]
# Feature	OPTIMIZE	VACUUM<br>
# Primary Goal	Query Speed (Read Performance)	Cost Savings (Storage Cleanup)
# Action	Creates new, larger files	Deletes old, unneeded files
# Effect on History	Preserves history (Time Travel works)	Removes history older than threshold
# Risk Level	Low	High (Data is permanently deleted)
