# %%
v_prof ="Teacher"
v_age=74
count_v=dbutils.notebook.run("Child Notebook 2025-10-24 07_32_14",600,{"profession":v_prof,"age":v_age})
print(f"Total no. of records for profession:{v_prof} and age:{v_age} is {count_v}")
