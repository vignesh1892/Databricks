# %%
#where we can't pass paramter, it uses the default paramters from child notebook
# %run "/Workspace/Repos/vigneshkumarifet@gmail.com/Databricks/Pyspark-workout/NB-Workflow/Child Notebook 2025-10-24 07_32_14"
