# %%
df = spark.table("databricks_practice.outputdb.bank_txns_stg")
df1 = df.filter(df.amount > 50000)
df1.write.mode("overwrite").saveAsTable("databricks_practice.inputdb.bank_txns_curated")
print("Data written to table databricks_practice.inputdb.bank_txns_curated")
