# %%
#job level param
profname=dbutils.widgets.get("prof")
df= spark.read.format("csv").option("header","true").load("/Volumes/databricks_practice/inputdb/customerdata/custs.txt")

df1=df.filter(df.profession == profname)
df1.write.mode("overwrite").saveAsTable("databricks_practice.outputdb.tblprof")
