# %%
data=[('virat','37 age',40000),
 ('rohit','38 age',50000)]
col=["name","age","sal"]
df =spark.createDataFrame(data,col)

df.show()
from pyspark.sql.functions import col,regexp_replace,cast
df.withColumn("age_2",regexp_replace(col("age"),"age","").cast("int")).show()
