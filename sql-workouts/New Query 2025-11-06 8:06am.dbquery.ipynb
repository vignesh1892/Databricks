-- %%
CREATE OR REPLACE TABLE databricks_practice.inputdb.tblelectiondata USING DELTA AS
SELECT
 *
FROM
  csv.`dbfs:/Volumes/databricks_practice/inputdb/election_data/election_data_2014.csv` WITH (inferSchema = "true", header = "true");
