-- %%
/*CREATE OR REPLACE TABLE databricks_practice.outputdb.tblstatesalesdata
AS
select state, round(sum(amount),2) as totalsales ,current_date as load_dt
from databricks_practice.inputdb.tbltxns 
group by state
order by state;

select * from databricks_practice.outputdb.tblstatesalesdata;*/
insert into databricks_practice.outputdb.tblstatesalesdata
select state, round(sum(amount),2) as totalsales,current_date as load_dt 
from databricks_practice.inputdb.tbltxns 
group by state
order by state;
