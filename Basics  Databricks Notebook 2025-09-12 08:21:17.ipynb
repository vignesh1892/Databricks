# %% [markdown]
# # Lab01: Basics about Databricks
# - Pyspark
# - SQL
# - Unity Catalog
# - Delta Lake
# - Delta live table

# %%
print("welcom puppy ma ")

# %%
dbutils.help()
dbutils.fs.help()
dbutils.fs.help("cp")#detail of single command
dbutils.widgets.help()

# %%
files=dbutils.fs.ls("/databricks-datasets/")  # Programmatic way to list files
display(files)

# %%
# %fs ls /
